# %%
path = '/mlbio_scratch/anagupta/luna/outputs/2025-05-25/23-20-51/test_results/luna_cnn_test_only/model_23-20-51_epoch_249/luna_cnn_test_only_results.csv'

import pandas as pd
# read the data
data = pd.read_csv(path)

# print the data
print(data)

# get mean of column "test/Spearman's Rank Correlation (Average)"
mean_spearman = data['test/Spearman\'s Rank Correlation (Average)'].mean()

# get mean of column "test/Spearman's Rank Correlation (Median)"
mean_spearman_median = data['test/Spearman\'s Rank Correlation (Median)'].mean()

# print the mean
print(f"Mean Spearman's Rank Correlation: {mean_spearman}")
print(f"Mean Spearman's Rank Correlation (Median): {mean_spearman_median}")
# Out:
#      test/epoch  test/precision  test/Spearman's Rank Correlation (Median)  \
# 0           249        0.291623                                   0.665317
# 1           249        0.253066                                   0.638408
# 2           249        0.162966                                   0.110118
# 3           249        0.226774                                   0.634297
# 4           249        0.365611                                   0.784631
# ..          ...             ...                                        ...
# 108         249        0.212345                                   0.225560
# 109         249        0.200160                                   0.296612
# 110         249        0.140601                                   0.439707
# 111         249        0.182365                                   0.250393
# 112         249        0.173868                                   0.379693
#
# ...
